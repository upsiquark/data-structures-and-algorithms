# %%
#Let's implement a linked list
#begin with the node class

class Node:
    def __init__(self, data, next_node=None):
        self.data = data
        self.next_node=next_node

# %%
#Let's implement a linked list class

class LinkedList:
    def __init__(self, first_node):
        self.first_node = first_node

# %%
#Let's implement a linked list class
#with reading

class LinkedList:
    def __init__(self, first_node):
        self.first_node = first_node

    def read(self, index):
        #Start at the first node
        current_node = first_node
        current_index = 0

        while (current_index < index):
            #Follow along the links
            #until we arrive at the desired index
            current_node = current_node.next_node
            current_index += 1

            #If we go past the end of our list
            #the value is nowhere to be found
            #we return none
            if not current_node:
                return None
    
        return current_node.data

# %%
#Let's implement a linked list class
#with reading and searching

class LinkedList:
    def __init__(self, first_node):
        self.first_node = first_node

    def read(self, index):
        #Start at the first node
        current_node = first_node
        current_index = 0

        while (current_index < index):
            #Follow along the links
            #until we arrive at the desired index
            current_node = current_node.next_node
            current_index += 1

            #If we go past the end of our list
            #the value is nowhere to be found
            #we return none
            if not current_node:
                return None
    
        return current_node.data

    def index_of(self, value):
        #Once again, begin at the first node
        current_node = first_node
        current_index = 0

        while current_node:
            #If the element we locate the element, 
            #return it
            if (current_node.data == value):
                return current_index

            #If we do not, proceed to the consequent node
            current_node = current_node.next_node
            current_index += 1

        #If we never find the element we are looking for
        #yet get to the end of the list
        #return none
        return None

# %%
#Let's implement a linked list class
#with reading, searching, and insertion

class LinkedList:
    def __init__(self, first_node):
        self.first_node = first_node

    def read(self, index):
        #Start at the first node
        current_node = first_node
        current_index = 0

        while (current_index < index):
            #Follow along the links
            #until we arrive at the desired index
            current_node = current_node.next_node
            current_index += 1

            #If we go past the end of our list
            #the value is nowhere to be found
            #we return none
            if not current_node:
                return None
    
        return current_node.data

    def index_of(self, value):
        #Once again, begin at the first node
        current_node = first_node
        current_index = 0

        while current_node:
            #If the element we locate the element, 
            #return it
            if (current_node.data == value):
                return current_index

            #If we do not, proceed to the consequent node
            current_node = current_node.next_node
            current_index += 1

        #If we never find the element we are looking for
        #yet get to the end of the list
        #return none
        return None

    def insert_at_index(self, index, value):
        #Create a new node
        new_node = Node(value)

        #If inserting at the start of the list
        if (index == 0):
            #The new node links to the former first node
            new_node.next_node = first_node
            #The new node is now the first node
            self.first_node = new_node
            return

        #If inserting anywhere else:
        current_node = first_node
        current_index = 0

        #Access the node preceding the planned location of the new node
        while (current_index < (index - 1)):
            current_node = current_node.next_node
            current_index += 1

        #The new node must link to the next node:
        new_node.next_node = current_node.next_node

        #The node preceding our new node
        #must point to the new node
        current_node.next_node = new_node

# %%
#Let's implement a linked list class
#with reading, searching, insertion, and deletion

class LinkedList:
    def __init__(self, first_node):
        self.first_node = first_node

    def read(self, index):
        #Start at the first node
        current_node = first_node
        current_index = 0

        while (current_index < index):
            #Follow along the links
            #until we arrive at the desired index
            current_node = current_node.next_node
            current_index += 1

            #If we go past the end of our list
            #the value is nowhere to be found
            #we return none
            if not current_node:
                return None
    
        return current_node.data

    def index_of(self, value):
        #Once again, begin at the first node
        current_node = first_node
        current_index = 0

        while current_node:
            #If the element we locate the element, 
            #return it
            if (current_node.data == value):
                return current_index

            #If we do not, proceed to the consequent node
            current_node = current_node.next_node
            current_index += 1

        #If we never find the element we are looking for
        #yet get to the end of the list
        #return none
        return None

    def insert_at_index(self, index, value):
        #Create a new node
        new_node = Node(value)

        #If inserting at the start of the list
        if (index == 0):
            #The new node links to the former first node
            new_node.next_node = first_node
            #The new node is now the first node
            self.first_node = new_node
            return

        #If inserting anywhere else:
        current_node = first_node
        current_index = 0

        #Access the node preceding the planned location of the new node
        while (current_index < (index - 1)):
            current_node = current_node.next_node
            current_index += 1

        #The new node must link to the next node:
        new_node.next_node = current_node.next_node

        #The node preceding our new node
        #must point to the new node
        current_node.next_node = new_node

    def delete_at_index(self, index):
        #When deleting at the first node:
        if index == 0:
            #The second node becomes the first node
            self.first_node = first_node.next_node

        current_node = first_node
        current_index = 0

        #Find the node preceding the one we will delete
        #this will be the current_node
        while current_index < (index - 1):
            current_node = current_node.next_node
            current_index += 1

        #Locate the node following the node we will delete
        node_after_deleted_node = current_node.next_node.next_node

        #The current node points to the node after the one we will delete
        #the node we want to delete is left out of the list
        current_node.next_node = node_after_deleted_node

# %%
#An implementation of a doubly linked list
#begin with a node class

class Node:
    def __init__(self, data, next_node, previous_node):
        self.data = data
        self.next_node = next_node
        self.previous_node = previous_node

# %%
#Then the doubly linked list class

class DoublyLinkedList:
    def __init__(self, first_node=None, last_node=None):
        self.first_node = first_node
        self.last_node = last_node

# %%
#Now an implementation of a doubly linked list 
#with insertion at the end

class Node:
    def __init__(self, data, next_node=None, previous_node=None):
        self.data = data
        self.next_node = next_node
        self.previous_node = previous_node

class DoublyLinkedList:
    def __init__(self, first_node=None, last_node=None):
        self.first_node = first_node
        self.last_node = last_node

    def insert_at_end(self, value):
        new_node = Node(value)

        #If the linked list is empty
        if not self.first_node:
            self.first_node = new_node
            self.last_node = new_node
        #If the linked list is non-empty:
        else:
            new_node.previous_node = self.last_node
            self.last_node.next_node = new_node
            self.last_node = new_node

# %%
#Now an implementation of a doubly linked list 
#with insertion and a Queue class

class Node:
    def __init__(self, data, next_node=None, previous_node=None):
        self.data = data
        self.next_node = next_node
        self.previous_node = previous_node

class DoublyLinkedList:
    def __init__(self, first_node=None, last_node=None):
        self.first_node = first_node
        self.last_node = last_node

    def insert_at_end(self, value):
        new_node = Node(value)

        #If the linked list is empty
        if not self.first_node:
            self.first_node = new_node
            self.last_node = new_node
        else:
            #If the linked list is non-empty:
            new_node.previous_node = self.last_node
            self.last_node.next_node = new_node
            self.last_node = new_node

        def remove_from_front(self):
            removed_node = self.first_node
            self.first_node = self.first_node.next_node
            return removed_node

class Queue:
    def __init__(self):
        self.data = DoublyLinkedList()

    def enqueue(self, element):
        self.data.insert_at_end(element)

    def dequeue(self):
        removed_node = self.data.remove_from_front
        return removed_node.data

    def read(self):
        if not self.data.first_node:
            return None
        return self.data.first_node.data

# %%
#Add a method to the classic linked list class that prints all the elements of the list

class Node:
    def __init__(self, data, next_node=None):
        self.data = data
        self.next_node=next_node

#Let's implement a linked list class
#with reading, searching, insertion, and deletion

class LinkedList:
    def __init__(self, first_node):
        self.first_node = first_node

    def read(self, index):
        #Start at the first node
        current_node = first_node
        current_index = 0

        while (current_index < index):
            #Follow along the links
            #until we arrive at the desired index
            current_node = current_node.next_node
            current_index += 1

            #If we go past the end of our list
            #the value is nowhere to be found
            #we return none
            if not current_node:
                return None
    
        return current_node.data

    def index_of(self, value):
        #Once again, begin at the first node
        current_node = first_node
        current_index = 0

        while current_node:
            #If the element we locate the element, 
            #return it
            if (current_node.data == value):
                return current_index

            #If we do not, proceed to the consequent node
            current_node = current_node.next_node
            current_index += 1

        #If we never find the element we are looking for
        #yet get to the end of the list
        #return none
        return None

    def insert_at_index(self, index, value):
        #Create a new node
        new_node = Node(value)

        #If inserting at the start of the list
        if (index == 0):
            #The new node links to the former first node
            new_node.next_node = self.first_node
            #The new node is now the first node
            self.first_node = new_node
            return

        #If inserting anywhere else:
        current_node = self.first_node
        current_index = 0

        #Access the node preceding the planned location of the new node
        while (current_index < (index - 1)):
            current_node = current_node.next_node
            current_index += 1

        #The new node must link to the next node:
        new_node.next_node = current_node.next_node

        #The node preceding our new node
        #must point to the new node
        current_node.next_node = new_node

    def delete_at_index(self, index):
        #When deleting at the first node:
        if index == 0:
            #The second node becomes the first node
            self.first_node = first_node.next_node

        current_node = self.first_node
        current_index = 0

        #Find the node preceding the one we will delete
        #this will be the current_node
        while current_index < (index - 1):
            current_node = current_node.next_node
            current_index += 1

        #Locate the node following the node we will delete
        node_after_deleted_node = current_node.next_node.next_node

        #The current node points to the node after the one we will delete
        #the node we want to delete is left out of the list
        current_node.next_node = node_after_deleted_node

    def print_in_order(self):
        current_node = self.first_node

        while current_node:
            print(current_node.data)
            current_node = current_node.next_node

# %%
#Now an implementation of a doubly linked list 
#with insertion at the end and printing in reverse order

class Node:
    def __init__(self, data, next_node=None, previous_node=None):
        self.data = data
        self.next_node = next_node
        self.previous_node = previous_node

class DoublyLinkedList:
    def __init__(self, first_node=None, last_node=None):
        self.first_node = first_node
        self.last_node = last_node

    def insert_at_end(self, value):
        new_node = Node(value)

        #If the linked list is empty
        if not self.first_node:
            self.first_node = new_node
            self.last_node = new_node
        #If the linked list is non-empty:
        else:
            new_node.previous_node = self.last_node
            self.last_node.next_node = new_node
            self.last_node = new_node
    def print_in_reverse(self):
        current_node = self.last_node

        while current_node:
            print(current_node.data)
            current_node = current_node.previous_node

# %%
#Add a method to the classic linked list class that returns the last element from the list.
#Assume you don't know how many elements are in the list

#Add a method to the classic linked list class that prints all the elements of the list

class Node:
    def __init__(self, data, next_node=None):
        self.data = data
        self.next_node=next_node

#Let's implement a linked list class
#with reading, searching, insertion, and deletion

class LinkedList:
    def __init__(self, first_node):
        self.first_node = first_node

    def read(self, index):
        #Start at the first node
        current_node = first_node
        current_index = 0

        while (current_index < index):
            #Follow along the links
            #until we arrive at the desired index
            current_node = current_node.next_node
            current_index += 1

            #If we go past the end of our list
            #the value is nowhere to be found
            #we return none
            if not current_node:
                return None
    
        return current_node.data

    def index_of(self, value):
        #Once again, begin at the first node
        current_node = first_node
        current_index = 0

        while current_node:
            #If the element we locate the element, 
            #return it
            if (current_node.data == value):
                return current_index

            #If we do not, proceed to the consequent node
            current_node = current_node.next_node
            current_index += 1

        #If we never find the element we are looking for
        #yet get to the end of the list
        #return none
        return None

    def insert_at_index(self, index, value):
        #Create a new node
        new_node = Node(value)

        #If inserting at the start of the list
        if (index == 0):
            #The new node links to the former first node
            new_node.next_node = self.first_node
            #The new node is now the first node
            self.first_node = new_node
            return

        #If inserting anywhere else:
        current_node = self.first_node
        current_index = 0

        #Access the node preceding the planned location of the new node
        while (current_index < (index - 1)):
            current_node = current_node.next_node
            current_index += 1

        #The new node must link to the next node:
        new_node.next_node = current_node.next_node

        #The node preceding our new node
        #must point to the new node
        current_node.next_node = new_node

    def delete_at_index(self, index):
        #When deleting at the first node:
        if index == 0:
            #The second node becomes the first node
            self.first_node = first_node.next_node

        current_node = self.first_node
        current_index = 0

        #Find the node preceding the one we will delete
        #this will be the current_node
        while current_index < (index - 1):
            current_node = current_node.next_node
            current_index += 1

        #Locate the node following the node we will delete
        node_after_deleted_node = current_node.next_node.next_node

        #The current node points to the node after the one we will delete
        #the node we want to delete is left out of the list
        current_node.next_node = node_after_deleted_node

    def print_in_order(self):
        current_node = self.first_node

        while current_node:
            print(current_node.data)
            current_node = current_node.next_node

    def find_last_element(self):
        current_node = self.first_node

        while current_node.next_node:
            current_node = current_node.next_node

        return current_node

# %%
#Add a method to the classic linked list class that reverses the list. 
#If A -> B -> C originally, then C -> B -> A after.

class Node:
    def __init__(self, data, next_node=None):
        self.data = data
        self.next_node=next_node
        
class LinkedList:
    def __init__(self, first_node):
        self.first_node = first_node

    def read(self, index):
        #Start at the first node
        current_node = first_node
        current_index = 0

        while (current_index < index):
            #Follow along the links
            #until we arrive at the desired index
            current_node = current_node.next_node
            current_index += 1

            #If we go past the end of our list
            #the value is nowhere to be found
            #we return none
            if not current_node:
                return None
    
        return current_node.data

    def index_of(self, value):
        #Once again, begin at the first node
        current_node = first_node
        current_index = 0

        while current_node:
            #If the element we locate the element, 
            #return it
            if (current_node.data == value):
                return current_index

            #If we do not, proceed to the consequent node
            current_node = current_node.next_node
            current_index += 1

        #If we never find the element we are looking for
        #yet get to the end of the list
        #return none
        return None

    def insert_at_index(self, index, value):
        #Create a new node
        new_node = Node(value)

        #If inserting at the start of the list
        if (index == 0):
            #The new node links to the former first node
            new_node.next_node = self.first_node
            #The new node is now the first node
            self.first_node = new_node
            return

        #If inserting anywhere else:
        current_node = self.first_node
        current_index = 0

        #Access the node preceding the planned location of the new node
        while (current_index < (index - 1)):
            current_node = current_node.next_node
            current_index += 1

        #The new node must link to the next node:
        new_node.next_node = current_node.next_node

        #The node preceding our new node
        #must point to the new node
        current_node.next_node = new_node

    def delete_at_index(self, index):
        #When deleting at the first node:
        if index == 0:
            #The second node becomes the first node
            self.first_node = first_node.next_node

        current_node = self.first_node
        current_index = 0

        #Find the node preceding the one we will delete
        #this will be the current_node
        while current_index < (index - 1):
            current_node = current_node.next_node
            current_index += 1

        #Locate the node following the node we will delete
        node_after_deleted_node = current_node.next_node.next_node

        #The current node points to the node after the one we will delete
        #the node we want to delete is left out of the list
        current_node.next_node = node_after_deleted_node

    def print_in_order(self):
        current_node = self.first_node

        while current_node:
            print(current_node.data)
            current_node = current_node.next_node

    def find_last_element(self):
        current_node = self.first_node

        while current_node.next_node:
            current_node = current_node.next_node

        return current_node

    def reversal(self):
        previous_node = None
        current_node = self.first_node

        while current_node:
            next_node = current_node.next_node
            current_node.next_node = previous_node
            previous_node = current_node
            current_node = next_node
        self.first_node = previous_node

# %%
#Say you have access to a node from somewhere in the middle of a classic linked list
#but not the linked list itself
#you have a variable that points to an instance of a Node but you don't have access to the linked list instance
#Write a code that will effectively delete this node from the list
#the remaining list should be complete with only this node gone

class Node:
    def __init__(self, data, next_node=None):
        self.data = data
        self.next_node=next_node
        
class LinkedList:
    def __init__(self, first_node):
        self.first_node = first_node

    def read(self, index):
        #Start at the first node
        current_node = first_node
        current_index = 0

        while (current_index < index):
            #Follow along the links
            #until we arrive at the desired index
            current_node = current_node.next_node
            current_index += 1

            #If we go past the end of our list
            #the value is nowhere to be found
            #we return none
            if not current_node:
                return None
    
        return current_node.data

    def index_of(self, value):
        #Once again, begin at the first node
        current_node = first_node
        current_index = 0

        while current_node:
            #If the element we locate the element, 
            #return it
            if (current_node.data == value):
                return current_index

            #If we do not, proceed to the consequent node
            current_node = current_node.next_node
            current_index += 1

        #If we never find the element we are looking for
        #yet get to the end of the list
        #return none
        return None

    def insert_at_index(self, index, value):
        #Create a new node
        new_node = Node(value)

        #If inserting at the start of the list
        if (index == 0):
            #The new node links to the former first node
            new_node.next_node = self.first_node
            #The new node is now the first node
            self.first_node = new_node
            return

        #If inserting anywhere else:
        current_node = self.first_node
        current_index = 0

        #Access the node preceding the planned location of the new node
        while (current_index < (index - 1)):
            current_node = current_node.next_node
            current_index += 1

        #The new node must link to the next node:
        new_node.next_node = current_node.next_node

        #The node preceding our new node
        #must point to the new node
        current_node.next_node = new_node

    def delete_at_index(self, index):
        #When deleting at the first node:
        if index == 0:
            #The second node becomes the first node
            self.first_node = first_node.next_node

        current_node = self.first_node
        current_index = 0

        #Find the node preceding the one we will delete
        #this will be the current_node
        while current_index < (index - 1):
            current_node = current_node.next_node
            current_index += 1

        #Locate the node following the node we will delete
        node_after_deleted_node = current_node.next_node.next_node

        #The current node points to the node after the one we will delete
        #the node we want to delete is left out of the list
        current_node.next_node = node_after_deleted_node

    def print_in_order(self):
        current_node = self.first_node

        while current_node:
            print(current_node.data)
            current_node = current_node.next_node

    def find_last_element(self):
        current_node = self.first_node

        while current_node.next_node:
            current_node = current_node.next_node

        return current_node

    def reversal(self):
        previous_node = None
        current_node = self.first_node

        while current_node:
            next_node = current_node.next_node
            current_node.next_node = previous_node
            previous_node = current_node
            current_node = next_node
        self.first_node = previous_node
    def remove_isolate(self, node):
        node.data = node.next_node.data
        node.next_node = node.next_node.next_node
